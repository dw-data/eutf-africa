# %%
import pandas as pd
import re
import altair as alt
pd.set_option("display.max_rows", 300)

# %%
# downloaded from https://frontex.europa.eu/we-know/migratory-map/ on 2022-02-08 -- max month DEC 2021
df=pd.read_csv('../data/Frontex-Monthly_detections_of_IBC_20220204.csv', delimiter=';')
df.head()
# Out:
#                   Route Border type or inland  Nationality  JAN2009  FEB2009  \
# 0  Western Balkan Route                  Land        Syria        0        0
# 1  Western Balkan Route                  Land  Afghanistan        0        0
# 2  Western Balkan Route                  Land       Turkey        3        4
# 3  Western Balkan Route                  Land        India        0        0
# 4  Western Balkan Route                  Land      Tunisia        1        0
#
#    MAR2009  APR2009  MAY2009  JUN2009  JUL2009  ...  MAR2021  APR2021  \
# 0        0        0        0        0        0  ...     1657     2424
# 1       54       34       51       35       75  ...      428      415
# 2        3        0        4        5        9  ...       30       22
# 3        0        0        0        0        0  ...        5        0
# 4        0        0        0        0        0  ...       22       18
#
#    MAY2021  JUN2021  JUL2021  AUG2021  SEP2021  OCT2021  NOV2021  DEC2021
# 0     2505     2440     2490     3651     6113     5913     4317     3018
# 1      354      793      904     1809     1951     1247     1487     2013
# 2       44       44      109       93      226      311      381      370
# 3        2       20       14       26       23      107      102      245
# 4       11       13       20       27       54      189      203      237
#
# [5 rows x 159 columns]

# %% [markdown]
# ## Data preparation

# %%
# make monthly columns into row
df.columns
# Out:
# Index(['Route', 'Border type or inland', 'Nationality', 'JAN2009', 'FEB2009',
#        'MAR2009', 'APR2009', 'MAY2009', 'JUN2009', 'JUL2009',
#        ...
#        'MAR2021', 'APR2021', 'MAY2021', 'JUN2021', 'JUL2021', 'AUG2021',
#        'SEP2021', 'OCT2021', 'NOV2021', 'DEC2021'],
#       dtype='object', length=159)

# %%
dfm = df.melt(id_vars=['Route', 'Border type or inland', 'Nationality'])
dfm.head()
# Out:
#                   Route Border type or inland  Nationality variable  value
# 0  Western Balkan Route                  Land        Syria  JAN2009      0
# 1  Western Balkan Route                  Land  Afghanistan  JAN2009      0
# 2  Western Balkan Route                  Land       Turkey  JAN2009      3
# 3  Western Balkan Route                  Land        India  JAN2009      0
# 4  Western Balkan Route                  Land      Tunisia  JAN2009      1

# %%
dfm.columns=(['Route', 'BorderType','Nationality','month-year','DetectedCrossings'])

# %%
dfm.head()
# Out:
#                   Route BorderType  Nationality month-year  DetectedCrossings
# 0  Western Balkan Route       Land        Syria    JAN2009                  0
# 1  Western Balkan Route       Land  Afghanistan    JAN2009                  0
# 2  Western Balkan Route       Land       Turkey    JAN2009                  3
# 3  Western Balkan Route       Land        India    JAN2009                  0
# 4  Western Balkan Route       Land      Tunisia    JAN2009                  1

# %%
# replace MMM code by number
dfm['month-year-reconfig']=[re.sub(r'(JAN)(\d\d\d\d)', '\g<2>-01', date) for date in dfm['month-year']]
dfm['month-year-reconfig']=[re.sub(r'(FEB)(\d\d\d\d)', '\g<2>-02', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(MAR)(\d\d\d\d)', '\g<2>-03', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(APR)(\d\d\d\d)', '\g<2>-04', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(MAY)(\d\d\d\d)', '\g<2>-05', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(JUN)(\d\d\d\d)', '\g<2>-06', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(JUL)(\d\d\d\d)', '\g<2>-07', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(AUG)(\d\d\d\d)', '\g<2>-08', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(SEP)(\d\d\d\d)', '\g<2>-09', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(OCT)(\d\d\d\d)', '\g<2>-10', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(NOV)(\d\d\d\d)', '\g<2>-11', date) for date in dfm['month-year-reconfig']]
dfm['month-year-reconfig']=[re.sub(r'(DEC)(\d\d\d\d)', '\g<2>-12', date) for date in dfm['month-year-reconfig']]

# %%
# convert to date
dfm['month-year-reconfig-parsed'] = pd.to_datetime(dfm['month-year-reconfig'], format='%Y-%m')

# %%
dfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129948 entries, 0 to 129947
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Route                       129948 non-null  object
#  1   BorderType                  129948 non-null  object
#  2   Nationality                 129948 non-null  object
#  3   month-year                  129948 non-null  object
#  4   DetectedCrossings           129948 non-null  int64
#  5   month-year-reconfig         129948 non-null  object
#  6   month-year-reconfig-parsed  129948 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(5)
# memory usage: 6.9+ MB

# %%
# merge with table holding country - region association
regions = pd.read_csv('../data/Frontex-adjusted_country-and-continent-codes-list.csv', delimiter=';')
regions.head()
# Out:
#   continent            region         subregion         country  M49 code  \
# 0      Asia     Southern Asia     Southern Asia     Afghanistan         4
# 1    Europe   Southern Europe   Southern Europe         Albania         8
# 2  Americas  Northern America  Northern America      Antarctica        10
# 3    Africa   Northern Africa   Northern Africa         Algeria        12
# 4   Oceania         Polynesia         Polynesia  American Samoa        16
#
#   ISO-alpha3 code ISO-alpha2 code Other groupings
# 0             AFG              AF        LDC LLDC
# 1             ALB              AL             NaN
# 2             ATA              AQ             NaN
# 3             DZA              DZ             NaN
# 4             ASM              AS            SIDS

# %%
dfmm = dfm.merge(regions, left_on='Nationality',right_on='country')

# %%
len(df.Nationality.value_counts())
# Out:
# 152

# %%
#three missing Nationalities: Unknown, Stateless, Third-country
len(dfmm.Nationality.value_counts())
# Out:
# 149

# %%
dfmm.head()
# Out:
#                          Route BorderType Nationality month-year  \
# 0         Western Balkan Route       Land       Syria    JAN2009
# 1  Central Mediterranean Route        Sea       Syria    JAN2009
# 2        Western African Route        Sea       Syria    JAN2009
# 3  Eastern Mediterranean Route       Land       Syria    JAN2009
# 4  Eastern Mediterranean Route        Sea       Syria    JAN2009
#
#    DetectedCrossings month-year-reconfig month-year-reconfig-parsed continent  \
# 0                  0             2009-01                 2009-01-01      Asia
# 1                  0             2009-01                 2009-01-01      Asia
# 2                  0             2009-01                 2009-01-01      Asia
# 3                 82             2009-01                 2009-01-01      Asia
# 4                  9             2009-01                 2009-01-01      Asia
#
#          region     subregion country  M49 code ISO-alpha3 code  \
# 0  Western Asia  Western Asia   Syria       760             SYR
# 1  Western Asia  Western Asia   Syria       760             SYR
# 2  Western Asia  Western Asia   Syria       760             SYR
# 3  Western Asia  Western Asia   Syria       760             SYR
# 4  Western Asia  Western Asia   Syria       760             SYR
#
#   ISO-alpha2 code Other groupings
# 0              SY             NaN
# 1              SY             NaN
# 2              SY             NaN
# 3              SY             NaN
# 4              SY             NaN

# %%
dfmm.columns
# Out:
# Index(['Route', 'BorderType', 'Nationality', 'month-year', 'DetectedCrossings',
#        'month-year-reconfig', 'month-year-reconfig-parsed', 'continent',
#        'region', 'subregion', 'country', 'M49 code', 'ISO-alpha3 code',
#        'ISO-alpha2 code', 'Other groupings'],
#       dtype='object')

# %%
dfmm=dfmm[['Route', 'BorderType', 'Nationality',  'month-year-reconfig-parsed','DetectedCrossings','continent','region',  'M49 code', 'ISO-alpha3 code','ISO-alpha2 code']]

# %%
dfmm.columns
# Out:
# Index(['Route', 'BorderType', 'Nationality', 'month-year-reconfig-parsed',
#        'DetectedCrossings', 'continent', 'region', 'M49 code',
#        'ISO-alpha3 code', 'ISO-alpha2 code'],
#       dtype='object')

# %%
dfmm.columns=(['Route', 'BorderType', 'Nationality', 'month-year-reconfig-parsed',
       'DetectedCrossings', 'continent', 'region', 'numericISO',
       'ISO3', 'ISO2'])

# %% [markdown]
# ## Crossings by region in 2020

# %%
#filter for 2020
dfmm_2020 = dfmm[(dfmm['month-year-reconfig-parsed']>='2015-01-01')&(dfmm['month-year-reconfig-parsed']<='2015-12-01')]

# %%
dfmm_2020['month-year-reconfig-parsed'].min()
# Out:
# Timestamp('2015-01-01 00:00:00')

# %%
dfmm_2020['month-year-reconfig-parsed'].max()
# Out:
# Timestamp('2015-12-01 00:00:00')

# %%
dfmm_2020_by_region = dfmm_2020.groupby(by='region')['DetectedCrossings'].sum().reset_index()
dfmm_2020_by_region
# Out:
#                              region  DetectedCrossings
# 0         Australia and New Zealand                  0
# 1                   Central America                  0
# 2                      Central Asia                128
# 3                      Eastern Asia                 13
# 4                    Eastern Europe                484
# 5   Latin America and the Caribbean                105
# 6                         Melanesia                  3
# 7                        Micronesia                  0
# 8                   Northern Africa              59792
# 9                  Northern America                  3
# 10                  Northern Europe                  1
# 11                        Polynesia                  0
# 12                    South America                 11
# 13               South-eastern Asia                 19
# 14                    Southern Asia              35026
# 15                  Southern Europe               1462
# 16               Sub-Saharan Africa              40557
# 17                     Western Asia              62164

# %%
dfm_unknown = dfm[(dfm['Nationality']=='Unknown')|(dfm['Nationality']=='Stateless')| (dfm['Nationality']=='Third-country')]
dfmm_2020_unknown = dfm_unknown[(dfm_unknown['month-year-reconfig-parsed']>='2015-01-01')&(dfm_unknown['month-year-reconfig-parsed']<='2015-12-01')]

# %%
dfmm_2020_unknown['DetectedCrossings'].sum()
# Out:
# 556434

# %%
overall_detected_crossings_2020 = dfmm_2020_unknown['DetectedCrossings'].sum() + dfmm_2020_by_region['DetectedCrossings'].sum()
overall_detected_crossings_2020
# Out:
# 756202

# %%
dfmm_2020_by_region['share_in_%'] = dfmm_2020_by_region['DetectedCrossings']/overall_detected_crossings_2020*100

# %%
dfmm_2020_by_region
# Out:
#                              region  DetectedCrossings  share_in_%
# 0         Australia and New Zealand                  0    0.000000
# 1                   Central America                  0    0.000000
# 2                      Central Asia                128    0.016927
# 3                      Eastern Asia                 13    0.001719
# 4                    Eastern Europe                484    0.064004
# 5   Latin America and the Caribbean                105    0.013885
# 6                         Melanesia                  3    0.000397
# 7                        Micronesia                  0    0.000000
# 8                   Northern Africa              59792    7.906882
# 9                  Northern America                  3    0.000397
# 10                  Northern Europe                  1    0.000132
# 11                        Polynesia                  0    0.000000
# 12                    South America                 11    0.001455
# 13               South-eastern Asia                 19    0.002513
# 14                    Southern Asia              35026    4.631831
# 15                  Southern Europe               1462    0.193335
# 16               Sub-Saharan Africa              40557    5.363250
# 17                     Western Asia              62164    8.220555

# %% [markdown]
# ## Crossings from African nationals

# %%
# filter for African countries
dfmm_africa = dfmm[dfmm['continent']=='Africa']
dfmm_africa.head()
# Out:
#                             Route BorderType Nationality  \
# 6084         Western Balkan Route       Land     Tunisia
# 6085  Central Mediterranean Route        Sea     Tunisia
# 6086        Western African Route        Sea     Tunisia
# 6087  Eastern Mediterranean Route       Land     Tunisia
# 6088  Eastern Mediterranean Route        Sea     Tunisia
#
#      month-year-reconfig-parsed  DetectedCrossings continent           region  \
# 6084                 2009-01-01                  1    Africa  Northern Africa
# 6085                 2009-01-01                686    Africa  Northern Africa
# 6086                 2009-01-01                  0    Africa  Northern Africa
# 6087                 2009-01-01                  1    Africa  Northern Africa
# 6088                 2009-01-01                  0    Africa  Northern Africa
#
#       numericISO ISO3 ISO2
# 6084         788  TUN   TN
# 6085         788  TUN   TN
# 6086         788  TUN   TN
# 6087         788  TUN   TN
# 6088         788  TUN   TN

# %%
# per route, create key
dfmm_africa['route-bordertype'] = dfmm_africa['Route']+'-'+dfmm_africa['BorderType']
dfmm_africa.head()
# Out:
# /var/folders/fk/_qbrt9ys18b6s2yb_kqblv1xt9_xg3/T/ipykernel_81633/409651077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmm_africa['route-bordertype'] = dfmm_africa['Route']+'-'+dfmm_africa['BorderType']
#                             Route BorderType Nationality  \
# 6084         Western Balkan Route       Land     Tunisia
# 6085  Central Mediterranean Route        Sea     Tunisia
# 6086        Western African Route        Sea     Tunisia
# 6087  Eastern Mediterranean Route       Land     Tunisia
# 6088  Eastern Mediterranean Route        Sea     Tunisia
#
#      month-year-reconfig-parsed  DetectedCrossings continent           region  \
# 6084                 2009-01-01                  1    Africa  Northern Africa
# 6085                 2009-01-01                686    Africa  Northern Africa
# 6086                 2009-01-01                  0    Africa  Northern Africa
# 6087                 2009-01-01                  1    Africa  Northern Africa
# 6088                 2009-01-01                  0    Africa  Northern Africa
#
#       numericISO ISO3 ISO2                  route-bordertype
# 6084         788  TUN   TN         Western Balkan Route-Land
# 6085         788  TUN   TN   Central Mediterranean Route-Sea
# 6086         788  TUN   TN         Western African Route-Sea
# 6087         788  TUN   TN  Eastern Mediterranean Route-Land
# 6088         788  TUN   TN   Eastern Mediterranean Route-Sea

# %% [markdown]
# # Data analysis

# %% [markdown]
# ## How has the number of detected crossings from African nationals evolved over time?

# %%
crossings_african_nationals = dfmm_africa.groupby(by='month-year-reconfig-parsed')['DetectedCrossings'].sum().reset_index()
crossings_african_nationals
# Out:
#     month-year-reconfig-parsed  DetectedCrossings
# 0                   2009-01-01               2655
# 1                   2009-02-01               2536
# 2                   2009-03-01               4135
# 3                   2009-04-01               2883
# 4                   2009-05-01               1648
# 5                   2009-06-01               1617
# 6                   2009-07-01               1932
# 7                   2009-08-01               1879
# 8                   2009-09-01               1935
# 9                   2009-10-01               2702
# 10                  2009-11-01               1082
# 11                  2009-12-01               1088
# 12                  2010-01-01                833
# 13                  2010-02-01               1180
# 14                  2010-03-01               1545
# 15                  2010-04-01                963
# 16                  2010-05-01               1090
# 17                  2010-06-01               1318
# 18                  2010-07-01               1565
# 19                  2010-08-01               3176
# 20                  2010-09-01               3784
# 21                  2010-10-01               3494
# 22                  2010-11-01               1959
# 130                 2019-11-01               4308
# 131                 2019-12-01               3823
# 132                 2020-01-01               4376
# 133                 2020-02-01               3873
# 134                 2020-03-01               2313
# 135                 2020-04-01               1211
# 136                 2020-05-01               2772
# 137                 2020-06-01               3103
# 138                 2020-07-01               8593
# 139                 2020-08-01               7141
# 140                 2020-09-01               9028
# 141                 2020-10-01              10880
# 142                 2020-11-01              14722
# 143                 2020-12-01               5948
# 144                 2021-01-01               4573
# 145                 2021-02-01               5082
# 146                 2021-03-01               4885
# 147                 2021-04-01               3302
# 148                 2021-05-01               6545
# 149                 2021-06-01               7314
# 150                 2021-07-01              11383
# 151                 2021-08-01              12165
# 152                 2021-09-01              13371
# 153                 2021-10-01              11868
# 154                 2021-11-01              11322
# 155                 2021-12-01               8539

# %%
alt.Chart(crossings_african_nationals).mark_line().encode(
    x='month-year-reconfig-parsed:T',
    y='DetectedCrossings'
)
# Out:
# alt.Chart(...)

# %%
crossings_african_nationals['year']=crossings_african_nationals['month-year-reconfig-parsed'].dt.year

# %%
crossings_african_nationals['year_parsed']=pd.to_datetime(crossings_african_nationals['year'], format='%Y')

# %%
crossings_african_nationals_yearly=crossings_african_nationals.groupby(by='year_parsed')['DetectedCrossings'].sum().reset_index()

# %%
crossings_african_nationals_yearly
# Out:
#    year_parsed  DetectedCrossings
# 0   2009-01-01              26092
# 1   2010-01-01              22644
# 2   2011-01-01              80373
# 3   2012-01-01              25834
# 4   2013-01-01              41985
# 5   2014-01-01             128922
# 6   2015-01-01             172191
# 7   2016-01-01             184390
# 8   2017-01-01             129697
# 9   2018-01-01              81866
# 10  2019-01-01              50987
# 11  2020-01-01              73960
# 12  2021-01-01             100349

# %%
alt.Chart(crossings_african_nationals_yearly, title='Frontex Detected Crossings from African nationals').mark_bar(width=20).encode(
    x='year_parsed',
    y='DetectedCrossings',
)
# Out:
# alt.Chart(...)

# %%
# filter for countries that receive EUTF money

# %%
edf = pd.read_csv('../data/EUTF-country-budget.csv',delimiter=',')
edf.head()
# Out:
#     country  money_from_all_documented_projects(reg+single)  ISO
# 0   Somalia                                     590870442.2  SOM
# 1     Sudan                                     553485934.9  SDN
# 2     Libya                                     396428927.3  LBY
# 3  Ethiopia                                     334563566.0  ETH
# 4     Niger                                     294621000.0  NER

# %%
dfmm_africa.head()
# Out:
#                             Route BorderType Nationality  \
# 6084         Western Balkan Route       Land     Tunisia
# 6085  Central Mediterranean Route        Sea     Tunisia
# 6086        Western African Route        Sea     Tunisia
# 6087  Eastern Mediterranean Route       Land     Tunisia
# 6088  Eastern Mediterranean Route        Sea     Tunisia
#
#      month-year-reconfig-parsed  DetectedCrossings continent           region  \
# 6084                 2009-01-01                  1    Africa  Northern Africa
# 6085                 2009-01-01                686    Africa  Northern Africa
# 6086                 2009-01-01                  0    Africa  Northern Africa
# 6087                 2009-01-01                  1    Africa  Northern Africa
# 6088                 2009-01-01                  0    Africa  Northern Africa
#
#       numericISO ISO3 ISO2                  route-bordertype
# 6084         788  TUN   TN         Western Balkan Route-Land
# 6085         788  TUN   TN   Central Mediterranean Route-Sea
# 6086         788  TUN   TN         Western African Route-Sea
# 6087         788  TUN   TN  Eastern Mediterranean Route-Land
# 6088         788  TUN   TN   Eastern Mediterranean Route-Sea

# %%
len(edf)
# Out:
# 35

# %%
dfmm_africa_edf = dfmm_africa.merge(edf, left_on='ISO3', right_on='ISO', how='outer')
dfmm_africa_edf.head()
# Out:
#                          Route BorderType Nationality  \
# 0         Western Balkan Route       Land     Tunisia
# 1  Central Mediterranean Route        Sea     Tunisia
# 2        Western African Route        Sea     Tunisia
# 3  Eastern Mediterranean Route       Land     Tunisia
# 4  Eastern Mediterranean Route        Sea     Tunisia
#
#   month-year-reconfig-parsed  DetectedCrossings continent           region  \
# 0                 2009-01-01                  1    Africa  Northern Africa
# 1                 2009-01-01                686    Africa  Northern Africa
# 2                 2009-01-01                  0    Africa  Northern Africa
# 3                 2009-01-01                  1    Africa  Northern Africa
# 4                 2009-01-01                  0    Africa  Northern Africa
#
#    numericISO ISO3 ISO2                  route-bordertype  country  \
# 0         788  TUN   TN         Western Balkan Route-Land  Tunisia
# 1         788  TUN   TN   Central Mediterranean Route-Sea  Tunisia
# 2         788  TUN   TN         Western African Route-Sea  Tunisia
# 3         788  TUN   TN  Eastern Mediterranean Route-Land  Tunisia
# 4         788  TUN   TN   Eastern Mediterranean Route-Sea  Tunisia
#
#    money_from_all_documented_projects(reg+single)  ISO
# 0                                      76450000.0  TUN
# 1                                      76450000.0  TUN
# 2                                      76450000.0  TUN
# 3                                      76450000.0  TUN
# 4                                      76450000.0  TUN

# %%
euft_african_countries = dfmm_africa_edf[dfmm_africa_edf['country'].notnull()]
euft_african_countries.head()
# Out:
#                          Route BorderType Nationality  \
# 0         Western Balkan Route       Land     Tunisia
# 1  Central Mediterranean Route        Sea     Tunisia
# 2        Western African Route        Sea     Tunisia
# 3  Eastern Mediterranean Route       Land     Tunisia
# 4  Eastern Mediterranean Route        Sea     Tunisia
#
#   month-year-reconfig-parsed  DetectedCrossings continent           region  \
# 0                 2009-01-01                  1    Africa  Northern Africa
# 1                 2009-01-01                686    Africa  Northern Africa
# 2                 2009-01-01                  0    Africa  Northern Africa
# 3                 2009-01-01                  1    Africa  Northern Africa
# 4                 2009-01-01                  0    Africa  Northern Africa
#
#    numericISO ISO3 ISO2                  route-bordertype  country  \
# 0         788  TUN   TN         Western Balkan Route-Land  Tunisia
# 1         788  TUN   TN   Central Mediterranean Route-Sea  Tunisia
# 2         788  TUN   TN         Western African Route-Sea  Tunisia
# 3         788  TUN   TN  Eastern Mediterranean Route-Land  Tunisia
# 4         788  TUN   TN   Eastern Mediterranean Route-Sea  Tunisia
#
#    money_from_all_documented_projects(reg+single)  ISO
# 0                                      76450000.0  TUN
# 1                                      76450000.0  TUN
# 2                                      76450000.0  TUN
# 3                                      76450000.0  TUN
# 4                                      76450000.0  TUN

# %%
len(euft_african_countries.Nationality.value_counts())
# Out:
# 35

# %%
crossings_eutf_recipients = euft_african_countries.groupby(by='month-year-reconfig-parsed')['DetectedCrossings'].sum().reset_index()

# %%
crossings_eutf_recipients
# Out:
#     month-year-reconfig-parsed  DetectedCrossings
# 0                   2009-01-01               2592
# 1                   2009-02-01               2521
# 2                   2009-03-01               4130
# 3                   2009-04-01               2876
# 111                 2018-04-01               4788
# 112                 2018-05-01               7226
# 113                 2018-06-01               9304
# 114                 2018-07-01               8183
# 115                 2018-08-01               8361
# 116                 2018-09-01               9014
# 117                 2018-10-01              11867
# 118                 2018-11-01               6025
# 119                 2018-12-01               5319
# 120                 2019-01-01               1253
# 121                 2019-02-01                850
# 122                 2019-03-01               1498
# 123                 2019-04-01               1345
# 124                 2019-05-01               2779
# 125                 2019-06-01               3584
# 126                 2019-07-01               3168
# 127                 2019-08-01               3838
# 128                 2019-09-01               6479
# 129                 2019-10-01               5316
# 130                 2019-11-01               2919
# 131                 2019-12-01               2092
# 132                 2020-01-01               3601
# 133                 2020-02-01               2797
# 134                 2020-03-01               1358
# 135                 2020-04-01                849
# 136                 2020-05-01               2600
# 137                 2020-06-01               2877
# 138                 2020-07-01               8057
# 139                 2020-08-01               6381
# 140                 2020-09-01               7747
# 141                 2020-10-01               8415
# 142                 2020-11-01              11525
# 143                 2020-12-01               4356
# 144                 2021-01-01               3130
# 145                 2021-02-01               4876
# 146                 2021-03-01               3890
# 147                 2021-04-01               2232
# 148                 2021-05-01               5905
# 149                 2021-06-01               6007
# 150                 2021-07-01              10566
# 151                 2021-08-01              10826
# 152                 2021-09-01              11391
# 153                 2021-10-01               9221
# 154                 2021-11-01               9453
# 155                 2021-12-01               6662

# %%
crossings_eutf_recipients['year']=crossings_eutf_recipients['month-year-reconfig-parsed'].dt.year
crossings_eutf_recipients['year_parsed']=pd.to_datetime(crossings_eutf_recipients['year'], format='%Y')
crossings_eutf_recipients_yearly=crossings_eutf_recipients.groupby(by='year_parsed')['DetectedCrossings'].sum().reset_index()

# %%
alt.Chart(crossings_eutf_recipients_yearly, title='Frontex Detected Crossings from African nationals from EUTF recipient countries').mark_bar(width=20, color='orange').encode(
    x='year_parsed',
    y='DetectedCrossings',
)
# Out:
# alt.Chart(...)

# %%
africa = alt.Chart(crossings_african_nationals_yearly, title='Frontex Detected Crossings from all African nationals (blue) and EUTF recipient countries (orange) ').mark_bar(width=20).encode(
    x='year_parsed',
    y='DetectedCrossings',
)

eutf = alt.Chart(crossings_eutf_recipients_yearly).mark_bar(width=7, color='orange').encode(
    x='year_parsed',
    y='DetectedCrossings',
)

combination = africa + eutf
combination
# Out:
# alt.LayerChart(...)

# %%
crossings_african_nationals_yearly
# Out:
#    year_parsed  DetectedCrossings
# 0   2009-01-01              26092
# 1   2010-01-01              22644
# 2   2011-01-01              80373
# 3   2012-01-01              25834
# 4   2013-01-01              41985
# 5   2014-01-01             128922
# 6   2015-01-01             172191
# 7   2016-01-01             184390
# 8   2017-01-01             129697
# 9   2018-01-01              81866
# 10  2019-01-01              50987
# 11  2020-01-01              73960
# 12  2021-01-01             100349

# %%
crossings_eutf_recipients_yearly
# Out:
#    year_parsed  DetectedCrossings
# 0   2009-01-01              25900
# 1   2010-01-01              22396
# 2   2011-01-01              68382
# 3   2012-01-01              24710
# 4   2013-01-01              41384
# 5   2014-01-01             101311
# 6   2015-01-01             160823
# 7   2016-01-01             181546
# 8   2017-01-01             127248
# 9   2018-01-01              80088
# 10  2019-01-01              35121
# 11  2020-01-01              60563
# 12  2021-01-01              84159
